# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
import numpy as np
import backyardworlds as bw
import matplotlib.pyplot as plt
import random
from astropy.io import fits
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Load the data
path = '/Users/jfilippazzo/Documents/Modules/backyardworlds/data/'
C = bw.ClassificationData(path+'classifications.csv', path+'subjects.txt')
# Out:
# Loading classifications... This takes a few minutes!
# Loading subjects... This also takes a few minutes!

# %% [markdown]
# Fetch the retired subjects by passing the desired number of clicks.

# %%
C.get_retired(50)
# Out:
# Retired: 15808

# %%
id = random.choice(C.retired)
sub = C.get_subject(id)
# Out:
# Subject id: 5476941
#
# Users:
#  not-logged-in-96266ee79df6ccce0d65
#  Hogman2001
#  DarkEcstasyX
#  luisestanqueiro
#  sturkire
#
# Frame 0 has 13 clicks from 5 users.
# Frame 1 has 13 clicks from 5 users.
# Frame 2 has 13 clicks from 5 users.
# Frame 3 has 13 clicks from 5 users.
#
#
# name       ra           dec       u   g   r   i   z   J   H   K    W1    W2     W3     W4   #
# ---- ------------- ------------- --- --- --- --- --- --- --- --- ----- ------ ------ ----- ---
#   -- 153.967822107 8.47652007675 nan nan nan nan nan nan nan nan   nan    nan    nan   nan  12
#   -- 153.969274701 8.55846155542 nan nan nan nan nan nan nan nan 17.35 16.739 12.195 8.654  16
#   --  153.96866253 8.59873078632 nan nan nan nan nan nan nan nan   nan    nan    nan   nan   8
# <div id='159f555e-162a-44f5-84f6-842131acc6aa'></div>
# <div id='37444453-097f-4dc9-9043-0db5686079ef'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-3074d5c9e0f9> in <module>()
#       1 id = random.choice(C.retired)
# ----> 2 sub = C.get_subject(id)
#
# /Users/jfilippazzo/Documents/Modules/backyardworlds/backyardworlds.py in get_subject(self, subject_id, radius, num, plot, verbose)
#     167                 # xlabels, ylabels  = get_coordinates(labels, meta)
#     168                 # ax.set_xticklabels(labels)
# --> 169             make_SED(results)
#     170             return subject
#     171
#
# /Users/jfilippazzo/Documents/Modules/backyardworlds/backyardworlds.py in make_SED(results)
#     274             plt.title('{}, {}'.format(source['ra'],source['dec']))
#     275             ax.errorbar(wave, flux, yerr=unc, marker='o', ls='none')
# --> 276             ax.set_xscale('log')
#     277             ax.set_yscale('log')
#     278             ax.set_xlim(0.2,5)
#
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in set_xscale(self, value, **kwargs)
#    2831             ax.stale = True
#    2832
# -> 2833         self.autoscale_view(scaley=False)
#    2834
#    2835     def get_xticks(self, minor=False):
#
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in autoscale_view(self, tight, scalex, scaley)
#    2166                 x1 += delta
#    2167             if not _tight:
# -> 2168                 x0, x1 = xlocator.view_limits(x0, x1)
#    2169             self.set_xbound(x0, x1)
#    2170
#
# /Users/jfilippazzo/miniconda3/envs/astroconda/lib/python3.5/site-packages/matplotlib/ticker.py in view_limits(self, vmin, vmax)
#    1615         if minpos <= 0 or not np.isfinite(minpos):
#    1616             raise ValueError(
# -> 1617                 "Data has no positive values, and therefore can not be "
#    1618                 "log-scaled.")
#    1619
#
# ValueError: Data has no positive values, and therefore can not be log-scaled.

# %%
# Check T6 dwarf!
name = 'WISE J110125.95+540052.8'
ra, dec = 165.3581627, 54.0146782
T5 = C.get_subject(5566284, verbose=True)
# Out:
# Subject id: 5566284
#
# Users:
#  BobFletcher
#  not-logged-in-810ae341fcaa1ced07c2
#  KhasanMokaev
#  not-logged-in-fed83cb32be696e3eb9c
#  RCastro
#  krompir
#
# Frame 0 has 42 clicks from 6 users.
# Frame 1 has 12 clicks from 5 users.
# Frame 2 has 12 clicks from 5 users.
# Frame 3 has 12 clicks from 5 users.
#
#
# name       ra           dec        u      g      r      i      z     J   H   K    W1     W2     W3     W4   #
# ---- ------------- ------------- ------ ------ ------ ------ ------ --- --- --- ------ ------ ------ ----- ---
#   -- 165.459060956 53.6219035376    nan    nan    nan    nan    nan nan nan nan    nan    nan    nan   nan   5
#   -- 165.456802708 53.5235683951 23.174 22.515 21.657 20.734 20.312 nan nan nan 16.641 16.485 12.603 8.543   9
#   -- 165.458266643 53.6059395994    nan    nan    nan    nan    nan nan nan nan 17.393 16.782 12.361 9.362   9
#   -- 165.457905878 53.5755388748    nan    nan    nan    nan    nan nan nan nan    nan    nan    nan   nan   5
#   -- 165.457575007 53.5085344268    nan    nan    nan    nan    nan nan nan nan    nan    nan    nan   nan   5
#   -- 165.458208312 53.5133174474    nan    nan    nan    nan    nan nan nan nan    nan    nan    nan   nan   9
#   -- 165.457994851 53.5098983999    nan    nan    nan    nan    nan nan nan nan    nan    nan    nan   nan   5
#   -- 165.457827463 53.6305734618   24.3 24.608 24.007 21.519 21.145 nan nan nan  16.42 16.383 12.861 9.279   5
#   -- 165.457407986 53.5020439271    nan    nan    nan    nan    nan nan nan nan    nan    nan    nan   nan   5
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Questions
#
# - Retirement number based on clicks per frame or per subject? Occasionally, someone clicks a subject 50 times in frame 3 but nowhere else.
# - Also parse the talk page for the subject to filter out #ghost, #artifact, etc?
# - What is the cluster click threshold?
# - This filters out movers though! Separate function to look for movers?

# %% [markdown]
# # Interesting subjects
# - 5468349

# %%
C.subjects[random.choice(range(len(C.retired)))]
# Out:
# <Row index=7826>
# subject_id     RA        Dec                                                   SIMBAD                                                                                                                                VizieR                                                                                                                                                                                                IRSA                                                                                                                                                                        images                                                                          MJD                              Center             Tilenum                                    Nearest
#   int64     float64    float64                                                 str100                                                                                                                                str170                                                                                                                                                                                               str225                                                                                                                                                                       str210                                                                         str34                             str33               int64                                      str79
# ---------- ---------- ---------- -------------------------------------------------------------------------------------------------- ------------------------------------------------------------------------------------------------------------------------------------------------------------------------ ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- -------------------------------------------------------------------------------------------------------------------------- ---------------------------------- ------------------------------- ------- ------------------------------------------------------------------------------
#    5191459 150.661176 -18.173333 http://simbad.u-strasbg.fr/simbad/sim-coo?Coord=150.10951+-25.452567&Radius=498&Radius.unit=arcsec http://vizier.u-strasbg.fr/viz-bin/VizieR?-source=&-out.add=_r&-out.add=_RAJ%2C_DEJ&-sort=_r&-to=&-out.max=20&-meta.ucd=2&-meta.foot=1&-c.rs=498&-c=150.10951+-25.452567 http://irsa.ipac.caltech.edu/applications/finderchart/#&id=Hydra_finderchart_finder_chart&projectId=finderchart&UserTargetWorldPt=150.10951;-25.452567;EQ_J2000&subsize=0.195556&sources=DSS,SDSS,2MASS,IRIS,WISE&DoSearch=true unwise-1500m258.x3.y5.e0.jpeg, unwise-1500m258.x3.y5.e1.jpeg, unwise-1500m258.x3.y5.e2.jpeg, unwise-1500m258.x3.y5.e3.jpeg 55345.9, 55536.1, 56810.2, 56998.0 R.A.= 150.10951 dec= -25.452567    7690 489886, 489877, 489884, 489893, 489878, 489894, 489876, 489892, 489887, 489869

# %%
sub
# Out:
# <Table length=62>
# classification_id             user_name              user_id ...    y    frame
#       int64                     str34                 int64  ... float64 int64
# ----------------- ---------------------------------- ------- ... ------- -----
#          27478425 not-logged-in-ba14fe41c56028722682       1 ...   220.0     2
#          27478425 not-logged-in-ba14fe41c56028722682       1 ...   220.0     3
#          27478425 not-logged-in-ba14fe41c56028722682       1 ...   220.0     0
#          27478425 not-logged-in-ba14fe41c56028722682       1 ...   220.0     1
#          27478425 not-logged-in-ba14fe41c56028722682       1 ...   210.0     1
#          27478425 not-logged-in-ba14fe41c56028722682       1 ...   477.0     1
#          27478425 not-logged-in-ba14fe41c56028722682       1 ...   477.0     2
#          27478425 not-logged-in-ba14fe41c56028722682       1 ...   209.0     2
#          27478425 not-logged-in-ba14fe41c56028722682       1 ...   214.0     3
#          27478425 not-logged-in-ba14fe41c56028722682       1 ...   214.0     0
#               ...                                ...     ... ...     ...   ...
#          27478425 not-logged-in-ba14fe41c56028722682       1 ...    99.0     2
#          27478425 not-logged-in-ba14fe41c56028722682       1 ...    98.0     3
#          27478425 not-logged-in-ba14fe41c56028722682       1 ...   489.0     2
#          27478425 not-logged-in-ba14fe41c56028722682       1 ...   489.0     0
#          27478425 not-logged-in-ba14fe41c56028722682       1 ...   489.0     1
#          27752095                            Haloboy       1 ...   205.0     0
#          27752095                            Haloboy       1 ...   217.0     3
#          27752095                            Haloboy       1 ...   231.0     0
#          27752095                            Haloboy       1 ...   226.0     2
#          27752095                            Haloboy       1 ...   373.0     3
