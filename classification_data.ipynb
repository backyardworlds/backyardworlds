# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
import numpy as np
import backyardworlds as bw
import matplotlib.pyplot as plt
import random
from astropy.io import fits
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Load the data (THIS TAKES A FEW MINUTES!)
path = '/Users/jfilippazzo/Documents/Modules/backyardworlds/data/'
C = bw.ClassificationData(path+'classifications.csv', path+'subjects.txt')
# Out:
# Loading classifications...
# Loading subjects...

# %% [markdown]
# Fetch the retired subjects by passing the desired number of clicks.

# %%
C.get_retired(50)
# Out:
# Retired: 15808

# %%
id = random.choice(C.retired)
sub = C.get_subject(id)
# Out:
# Subject id: 5730264
#
# Users:
#  ws21040
#  not-logged-in-607487cb10de9152b488
#  MajorTom76
#  titigavroche64
#  BelindaSpinosi
#  not-logged-in-2b42661de26e3f2e80f9
#
# Frame 0 has 18 clicks from 5 users.
# Frame 1 has 11 clicks from 4 users.
# Frame 2 has 19 clicks from 6 users.
# Frame 3 has 15 clicks from 5 users.
#
#
#      name           ra           dec       J   H   K    W1     W2    #
# ------------- ------------- ------------- --- --- --- ------ ------ ---
# Not in Simbad 161.601430352 19.2635073465 nan nan nan 15.775 15.464  14
# Not in Simbad 161.601665517 19.2144420362 nan nan nan    nan    nan  12
# Not in Simbad 161.601906873 19.1664758876 nan nan nan 16.836 16.216  13
# <img src="data:image/png;base64,...">

# %%
# Check T6 dwarf!
T5 = C.get_subject(5566284, verbose=True)
# Out:
# Subject id: 5566284
#
# Users:
#  not-logged-in-810ae341fcaa1ced07c2
#  RCastro
#  krompir
#  BobFletcher
#  not-logged-in-fed83cb32be696e3eb9c
#  KhasanMokaev
#
# Frame 0 has 42 clicks from 6 users.
# Frame 1 has 12 clicks from 5 users.
# Frame 2 has 12 clicks from 5 users.
# Frame 3 has 12 clicks from 5 users.
#
#
#      name           ra           dec         J      H      K      W1     W2    #
# ------------- ------------- -------------- ------ ------ ------ ------ ------ ---
# Not in Simbad 154.934950956 -4.95059935768    nan    nan    nan    nan    nan   5
# Not in Simbad 154.932692708 -5.04783608977    nan    nan    nan    nan    nan   9
# Not in Simbad 154.934156643 -4.96613616794    nan    nan    nan    nan    nan   9
# Not in Simbad 154.933795878 -4.99639530461    nan    nan    nan    nan    nan   5
# Not in Simbad 154.933465007  -5.0633813848    nan    nan    nan    nan    nan   5
# Not in Simbad 154.934098312 -5.05893819424    nan    nan    nan 17.132 16.792   9
# Not in Simbad 154.933884851 -5.06224996409    nan    nan    nan 17.132 16.792   5
# Not in Simbad 154.933717463 -4.94115787368 13.307 12.684 12.464 12.349 12.206   5
# Not in Simbad 154.933297986 -5.06979253002    nan    nan    nan 17.596 17.315   5
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Questions
#
# - Retirement number based on clicks per frame or per subject? Occasionally, someone clicks a subject 50 times in frame 3 but nowhere else.
# - Also parse the talk page for the subject to filter out #ghost, #artifact, etc?
# - What is the cluster click threshold?
# - This filters out movers though! Separate function to look for movers?

# %%
#Mike Brown believes it is between Aldebaran and the Pleides
